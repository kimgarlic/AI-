# %% [markdown]
# ## pandas 라이브러리
# - csv, xlsx, json 업로드 하고 실습
# - df_sample.csv , nation.xlsx, df_sample.json

# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#파일 직접 업로드하기
from google.colab import files
myfile = files.upload()

# %%
import pandas as pd

# csv 파일 불러오기
# csv : comma separated values

df = pd.read_csv( "df_sample.csv",  header=0)
df

# %%
df = pd.read_csv( "df_sample.csv", header=1)
df

# %%
df = pd.read_csv( "df_sample.csv", header=None)
df

# %%
# 인덱스 지정

df = pd.read_csv( "df_sample.csv", index_col=False)
df

# %%
df = pd.read_csv( "df_sample.csv", index_col='name')
df

# %% [markdown]
# ## pandas 라이브러리
# - 파일 입출력 : xlsx

# %%
import pandas as pd

df = pd.read_excel('nation.xlsx' )
df
# Out:
#   국적코드  성별    입국객수    증가수
# 0  A01  남성  125000   8000
# 1  A01  여성  130000  10000
# 2  A05  남성     300     10
# 3  A05  여성     200     50
# 4  A06  남성  158912  24486
# 5  A06  여성  325000  63466

# %%
df = pd.read_excel('nation.xlsx' , index_col='국적코드')
df

# %% [markdown]
# ## pandas 라이브러리
# 파일 입출력 : json

# %%
import pandas as pd

df = pd.read_json('df_sample.json' )
df
# Out:
#            name  year        developer opensource
# pandas           2008    Wes Mckinneye       True
# NumPy            2006  Travis Oliphant       True
# matplotlib       2003   John D. Hunter       True

# %%
# 파일 저장

df.to_csv('save_df.csv')
df.to_excel('save_df.xlsx')
df.to_json('save_df.json')
